# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# #### Document Structure
#
# Core Components:
#
# • page_content (str)
#
# • metadata (dict)

# %%
## Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Krish Naik",
        "data_created":"2025-01-01"
    }
)

print(type(doc))

doc
# Out:
# <class 'langchain_core.documents.base.Document'>
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'data_created': '2025-01-01'}, page_content='This is the main text content I am using to create RAG')

# %%
## Create a simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

    "../data/text_files/machine_learning.txt":"""Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(content)
        
print("✅ Simple text files created!")
# Out:
# ✅ Simple text files created!

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %% [markdown]
# Now, we got data in document structure for `python_intro.txt` file.

# %%
## Directory Loader

from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader(
    '../data/text_files',
    glob='**/*.txt',
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)

documents = loader.load()
documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 2556.72it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# For PDF file

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

loader = DirectoryLoader(
    '../data/pdf',
    glob='**/*.pdf',
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.14', 'creator': 'LaTeX with hyperref package', 'creationdate': '2014-07-06T13:16:54+02:00', 'source': '..\\data\\pdf\\food101_paper.pdf', 'file_path': '..\\data\\pdf\\food101_paper.pdf', 'total_pages': 16, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2014-07-06T13:16:54+02:00', 'trapped': '', 'modDate': "D:20140706131654+02'00'", 'creationDate': "D:20140706131654+02'00'", 'page': 0}, page_content='Food-101 – Mining Discriminative Components\nwith Random Forests\nLukas Bossard1\nMatthieu Guillaumin1\nLuc Van Gool1,2\n1Computer Vision Lab, ETH Z¨urich, Switzerland\nlastname@vision.ee.ethz.ch\n2ESAT, PSI-VISICS, K.U. Leuven, Belgium\nvangool@esat.kuleuven.be\nAbstract. In this paper we address the problem of automatically rec-\nognizing pictured dishes. To this end, we introduce a novel method to\nmine discriminative parts using Random Forests (rf), which allows us\nto mine for parts simultaneously for all classes and to share knowledge\namong them. To improve eﬃciency of mining and classiﬁcation, we only\nconsider patches that are aligned with image superpixels, which we call\ncomponents. To measure the performance of our rf component mining\nfor food recognition, we introduce a novel and challenging dataset of\n101 food categories, with 101’000 images. With an average accuracy of\n50.76%, our model outperforms alternative classiﬁcation methods except\nfor cnn, including svm classiﬁcation on Improved Fisher Vectors and\nexisting discriminative part-mining algorithms by 11.88% and 8.13%, re-\nspectively. On the challenging mit-Indoor dataset, our method compares\nnicely to other s-o-a component-based classiﬁcation methods.\nKeywords: Image classiﬁcation, Discriminative part mining, Random\nForest, Food recognition\n1\nIntroduction\nFood is an important part of everyday life. This clearly ripples through into dig-\nital life, as illustrated by the abundance of food photography in social networks,\ndedicated photo sharing sites and mobile applications.1 Automatic recognition\nof dishes would not only help users eﬀortlessly organize their extensive photo col-\nlections but would also help online photo repositories make their content more\naccessible. Additionally, mobile food photography is now used to help patients\nestimate and track their daily calory intake, outside of any constraining clin-\nical environment. However, current systems resort to nutrition experts [27] or\nAmazon Mechanical Turk [30] to label food items.\nDespite these numerous applications, the problem of recognizing dishes and\nthe composition of their ingredients has not been fully addressed by the computer\nvision community. This is not due to the lack of challenges. In contrast to scene\n1 E.g.: foodspotting.com, sharedappetite.com, foodgawker.com, etc.'), Document(metadata={'producer': 'pdfTeX-1.40.14', 'creator': 'LaTeX with hyperref package', 'creationdate': '2014-07-06T13:16:54+02:00', 'source': '..\\data\\pdf\\food101_paper.pdf', 'file_path': '..\\data\\pdf\\food101_paper.pdf', 'total_pages': 16, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2014-07-06T13:16:54+02:00', 'trapped': '', 'modDate': "D:20140706131654+02'00'", 'creationDate': "D:20140706131654+02'00'", 'page': 1}, page_content='2\nL. Bossard, M. Guillaumin, L. Van Gool\nFig. 1: Typical examples of our dataset and corresponding mined components.\nFrom left to right: baby back ribs, chocolate cake, hot and sour soup, caesar\nsalad, eggs benedict. [All our ﬁgures are best viewed in color]\nclassiﬁcation or object detection, food typically does not exhibit any distinctive\nspatial layout: while we can decompose an outdoor scene with a ground plane, a\nhorizon and a sky region, or a human as a trunk with a head and limbs, we cannot\nﬁnd similar patterns relating ingredients of a mixed salad. The point of view, the\nlighting conditions, but also (and not least) the  ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
